# %% [markdown]
# #                  Exploratory Data Analysis J-Component(CSE5007)
#
# ##                                    Breast Cancer Data Analysis

# %% [markdown]
# ### Instructor: Bharadwaja Kumar
# ###                                                                          Team:
# ####                                                                                          Bhargavinath Dornadula (20MCB1011)
# ####                                                                                          Renuga Keerthi (20MCB1017)
# ####                                                                                          Heer Mapara (20MCB1019)
# ####                                                                                          John Mathew (20MCB1001)

# %%
import pandas as pd
import numpy  as np

# %%
full_data = pd.read_csv('data.csv')
full_data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25             NaN     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0              NaN           0.27760          0.3001               0.1471
# 1          0.08474           0.07864          0.0869                  NaN
# 2          0.10960           0.15990          0.1974               0.1279
# 3          0.14250           0.28390          0.2414               0.1052
# 4          0.10030           0.13280          0.1980               0.1043
#
# ...

# %%
full_data.columns
# Out:
# Index(['id', 'diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean',
#        'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean',
#        'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean',
#        'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se',
#        'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se',
#        'fractal_dimension_se', 'radius_worst', 'texture_worst',
#        'perimeter_worst', 'area_worst', 'smoothness_worst',
#        'compactness_worst', 'concavity_worst', 'concave points_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
full_data.shape
# Out:
# (569, 32)

# %%
full_data['diagnosis'].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
import seaborn as sns # data visualization library  
import matplotlib.pyplot as plt
y = full_data.diagnosis   
ax = sns.countplot(y,label="Count")       # M = 212, B = 357
B, M = y.value_counts()
print('Number of Benign: ',B)
print('Number of Malignant : ',M)
# Out:
# Number of Benign:  357
# Number of Malignant :  212
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
full_data['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
full_data.isnull().sum()
# Out:
# id                          0
# diagnosis                   0
# radius_mean                26
# texture_mean                0
# perimeter_mean             22
# area_mean                   0
# smoothness_mean            18
# compactness_mean            0
# concavity_mean              0
# concave points_mean        20
# symmetry_mean               0
# fractal_dimension_mean      0
# radius_se                  19
# texture_se                  0
# perimeter_se                0
# area_se                    15
# smoothness_se               0
# compactness_se              0
# concavity_se                0
# concave points_se           0
# symmetry_se                13
# fractal_dimension_se        0
# radius_worst                0
# texture_worst               0
# perimeter_worst            21
# area_worst                  0
# smoothness_worst            0
# compactness_worst          17
# concavity_worst             0
# concave points_worst        0
# symmetry_worst              0
# ...

# %%
full_data['diagnosis'] = np.where(full_data['diagnosis'] == 'M',1,0)
full_data.head()
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          1        17.99         10.38          122.80     1001.0
# 1    842517          1        20.57         17.77          132.90     1326.0
# 2  84300903          1        19.69         21.25             NaN     1203.0
# 3  84348301          1        11.42         20.38           77.58      386.1
# 4  84358402          1        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0              NaN           0.27760          0.3001               0.1471
# 1          0.08474           0.07864          0.0869                  NaN
# 2          0.10960           0.15990          0.1974               0.1279
# 3          0.14250           0.28390          0.2414               0.1052
# 4          0.10030           0.13280          0.1980               0.1043
#
# ...

# %%
full_data.isnull().any()
# Out:
# id                         False
# diagnosis                  False
# radius_mean                 True
# texture_mean               False
# perimeter_mean              True
# area_mean                  False
# smoothness_mean             True
# compactness_mean           False
# concavity_mean             False
# concave points_mean         True
# symmetry_mean              False
# fractal_dimension_mean     False
# radius_se                   True
# texture_se                 False
# perimeter_se               False
# area_se                     True
# smoothness_se              False
# compactness_se             False
# concavity_se               False
# concave points_se          False
# symmetry_se                 True
# fractal_dimension_se       False
# radius_worst               False
# texture_worst              False
# perimeter_worst             True
# area_worst                 False
# smoothness_worst           False
# compactness_worst           True
# ...

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    int32
#  2   radius_mean              543 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           547 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          551 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      549 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                550 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
full_data.describe()
# Out:
#                  id   diagnosis  radius_mean  texture_mean  perimeter_mean  \
# count  5.690000e+02  569.000000   543.000000    569.000000      547.000000
# mean   3.037183e+07    0.372583    14.124381     19.289649       91.888373
# std    1.250206e+08    0.483918     3.524952      4.301036       24.112560
# min    8.670000e+03    0.000000     6.981000      9.710000       43.790000
# 25%    8.692180e+05    0.000000    11.705000     16.170000       75.265000
# 50%    9.060240e+05    0.000000    13.370000     18.840000       86.240000
# 75%    8.813129e+06    1.000000    15.780000     21.800000      103.950000
# max    9.113205e+08    1.000000    28.110000     39.280000      188.500000
#
#          area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# count   569.000000       551.000000        569.000000      569.000000
# mean    654.889104         0.096389          0.104341        0.088799
# std     351.914129         0.014092          0.052813        0.079720
# ...

# %% [markdown]
# ## 1)using mean:

# %%
full_data['radius_mean'].fillna(full_data['radius_mean'].mean(),inplace=True)
full_data['perimeter_mean'].fillna(full_data['perimeter_mean'].mean(),inplace=True)

# %%
full_data.radius_mean
# Out:
# 0      17.990000
# 1      20.570000
# 2      19.690000
# 3      11.420000
# 4      20.290000
#          ...
# 564    21.560000
# 565    20.130000
# 566    16.600000
# 567    20.600000
# 568    14.124381
# Name: radius_mean, Length: 569, dtype: float64

# %%
full_data.perimeter_mean
# Out:
# 0      122.800000
# 1      132.900000
# 2       91.888373
# 3       77.580000
# 4      135.100000
#           ...
# 564    142.000000
# 565    131.200000
# 566    108.300000
# 567    140.100000
# 568     47.920000
# Name: perimeter_mean, Length: 569, dtype: float64

# %%
full_data.isnull().any()
# Out:
# id                         False
# diagnosis                  False
# radius_mean                False
# texture_mean               False
# perimeter_mean             False
# area_mean                  False
# smoothness_mean             True
# compactness_mean           False
# concavity_mean             False
# concave points_mean         True
# symmetry_mean              False
# fractal_dimension_mean     False
# radius_se                   True
# texture_se                 False
# perimeter_se               False
# area_se                     True
# smoothness_se              False
# compactness_se             False
# concavity_se               False
# concave points_se          False
# symmetry_se                 True
# fractal_dimension_se       False
# radius_worst               False
# texture_worst              False
# perimeter_worst             True
# area_worst                 False
# smoothness_worst           False
# compactness_worst           True
# ...

# %% [markdown]
# ## 2)using KNN

# %%
from sklearn.impute import KNNImputer
NaN=np.NaN
imputer=KNNImputer(n_neighbors=2, weights="uniform")
full_data[['smoothness_mean','concave points_mean','radius_se']]=imputer.fit_transform(full_data[['smoothness_mean','concave points_mean','radius_se']])

# %%
full_data[['smoothness_mean','concave points_mean','radius_se']]
# Out:
#      smoothness_mean  concave points_mean  radius_se
# 0            0.11225              0.14710    0.75525
# 1            0.08474              0.01828    0.54350
# 2            0.10960              0.12790    0.74560
# 3            0.14250              0.10520    0.49560
# 4            0.10030              0.10430    0.75720
# ..               ...                  ...        ...
# 564          0.11100              0.13890    1.17600
# 565          0.09780              0.09791    0.76550
# 566          0.08455              0.05302    0.45640
# 567          0.11780              0.15200    0.72600
# 568          0.05263              0.00000    0.21360
#
# [569 rows x 3 columns]

# %% [markdown]
# ## 3)Interpolate

# %%
full_data['area_se'].interpolate(method='linear',limit_direction='both',inplace=True)
full_data['compactness_worst'].interpolate(method='linear',limit_direction='both',inplace=True)

# %%
full_data['area_se'].isnull().sum()
full_data['compactness_worst'].isnull().sum()
# Out:
# 0

# %%
full_data.isnull().any()
# Out:
# id                         False
# diagnosis                  False
# radius_mean                False
# texture_mean               False
# perimeter_mean             False
# area_mean                  False
# smoothness_mean            False
# compactness_mean           False
# concavity_mean             False
# concave points_mean        False
# symmetry_mean              False
# fractal_dimension_mean     False
# radius_se                  False
# texture_se                 False
# perimeter_se               False
# area_se                    False
# smoothness_se              False
# compactness_se             False
# concavity_se               False
# concave points_se          False
# symmetry_se                 True
# fractal_dimension_se       False
# radius_worst               False
# texture_worst              False
# perimeter_worst             True
# area_worst                 False
# smoothness_worst           False
# compactness_worst          False
# ...

# %% [markdown]
# ## 4)fillforward and fillbackward

# %%
full_data['symmetry_se'].fillna(method='ffill',inplace=True)

# %%
full_data['symmetry_se'].isnull().sum()
# Out:
# 0

# %%
full_data['perimeter_worst'].fillna(method='bfill',inplace=True)

# %%
full_data['perimeter_worst'].isnull().sum()
# Out:
# 0

# %%
full_data.isnull().any()
# Out:
# id                         False
# diagnosis                  False
# radius_mean                False
# texture_mean               False
# perimeter_mean             False
# area_mean                  False
# smoothness_mean            False
# compactness_mean           False
# concavity_mean             False
# concave points_mean        False
# symmetry_mean              False
# fractal_dimension_mean     False
# radius_se                  False
# texture_se                 False
# perimeter_se               False
# area_se                    False
# smoothness_se              False
# compactness_se             False
# concavity_se               False
# concave points_se          False
# symmetry_se                False
# fractal_dimension_se       False
# radius_worst               False
# texture_worst              False
# perimeter_worst            False
# area_worst                 False
# smoothness_worst           False
# compactness_worst          False
# ...

# %% [markdown]
# VISUALIZATION

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
import seaborn as sns

# %%
data = pd.read_csv('data.csv');

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              543 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           547 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          551 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      549 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                550 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25             NaN     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0              NaN           0.27760          0.3001               0.1471
# 1          0.08474           0.07864          0.0869                  NaN
# 2          0.10960           0.15990          0.1974               0.1279
# 3          0.14250           0.28390          0.2414               0.1052
# 4          0.10030           0.13280          0.1980               0.1043
#
# ...

# %%
# Mapping Benign to 0 and Malignant to 1 
data['diagnosis'] = data['diagnosis'].map({'M':1,'B':0})
#Check the data stats
data.describe()
# Out:
#                  id   diagnosis  radius_mean  texture_mean  perimeter_mean  \
# count  5.690000e+02  569.000000   543.000000    569.000000      547.000000
# mean   3.037183e+07    0.372583    14.124381     19.289649       91.888373
# std    1.250206e+08    0.483918     3.524952      4.301036       24.112560
# min    8.670000e+03    0.000000     6.981000      9.710000       43.790000
# 25%    8.692180e+05    0.000000    11.705000     16.170000       75.265000
# 50%    9.060240e+05    0.000000    13.370000     18.840000       86.240000
# 75%    8.813129e+06    1.000000    15.780000     21.800000      103.950000
# max    9.113205e+08    1.000000    28.110000     39.280000      188.500000
#
#          area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# count   569.000000       551.000000        569.000000      569.000000
# mean    654.889104         0.096389          0.104341        0.088799
# std     351.914129         0.014092          0.052813        0.079720
# ...

# %%
# Scaling the dataset
datas = pd.DataFrame(preprocessing.scale(data.iloc[:,1:32]))
datas.columns = list(data.iloc[:,1:32].columns)
datas['diagnosis'] = data['diagnosis']
datas.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          1     1.097656     -2.073335        1.283145   0.984375
# 1          1     1.830255     -0.353632        1.702398   1.908708
# 2          1     1.580376      0.456187             NaN   1.558884
# 3          1    -0.767918      0.253732       -0.593942  -0.764464
# 4          1     1.750749     -1.151816        1.793720   1.826229
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0              NaN          3.283515        2.652874             2.577218
# 1        -0.827406         -0.487072       -0.023846                  NaN
# 2         0.938286          1.052926        1.363478             2.074971
# 3         3.275023          3.402909        1.915897             1.481169
# 4         0.277749          0.539340        1.371011             1.457626
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
# y includes our labels and x includes our features
y = data.diagnosis                          # M or B 
list = ['id','diagnosis']
x = data.drop(list,axis = 1 )
x.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0              NaN
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25             NaN     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001               0.1471         0.2419
# 1           0.07864          0.0869                  NaN         0.1812
# 2           0.15990          0.1974               0.1279         0.2069
# 3           0.28390          0.2414               0.1052         0.2597
# 4           0.13280          0.1980               0.1043         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
radius = data[['radius_mean','radius_se','radius_worst','diagnosis']]
sns.pairplot(radius, hue='diagnosis',palette="husl", markers=["o", "s"],size=4)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.pairplot(radius,kind="reg",size=4)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
g = sns.PairGrid(radius,hue='diagnosis', palette="Set1",size=4)
g = g.map_diag(plt.hist)
g = g.map_offdiag(plt.scatter, s = 3)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\seaborn\axisgrid.py:1150: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(UserWarning(msg))
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
g = sns.PairGrid(radius, hue="diagnosis", palette="Set2",size=4,hue_kws={"marker": ["o", "s"]})
g = g.map(plt.scatter, linewidths=1, edgecolor="w", s=40)
g = g.add_legend()
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\seaborn\axisgrid.py:1150: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(UserWarning(msg))

# %%
texture = data[['texture_mean','texture_se','texture_worst','diagnosis']]
sns.pairplot(texture, hue='diagnosis', palette="Blues_d",size=4, kind="reg")
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
perimeter = data[['perimeter_mean','perimeter_se','perimeter_worst','diagnosis']]
sns.pairplot(perimeter, hue='diagnosis', size = 4, kind="reg")
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
area = data[['area_mean','area_se','area_worst','diagnosis']]
sns.pairplot(area, hue='diagnosis', size =4)
# Out:
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\seaborn\axisgrid.py:1912: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
smoothness = data[['smoothness_mean','smoothness_se','smoothness_worst','diagnosis']]
sns.pairplot(smoothness, hue='diagnosis')

# %%
concavity = data[['concavity_mean','concavity_se','concavity_worst','diagnosis']]
sns.pairplot(concavity, hue='diagnosis')

# %%
concave_points = data[['concave points_mean','concave points_se','concave points_worst','diagnosis']]
sns.pairplot(concave_points, hue='diagnosis')

# %%
symmetry = data[['symmetry_mean','symmetry_se','symmetry_worst','diagnosis']]
sns.pairplot(symmetry, hue='diagnosis')

# %%
fractal_dimension = data[['fractal_dimension_mean','fractal_dimension_se','fractal_dimension_worst','diagnosis']]
sns.pairplot(fractal_dimension, hue='diagnosis')

# %%
features_mean = data.columns[1:9]
features_se = data.columns[9:19]
features_worst = data.columns[1]

# %%
malignant = data[data['diagnosis'] ==1]
benign = data[data['diagnosis'] ==0]

# %%
plt.figure(figsize=(15,15))
for i, feature in enumerate(features_mean):
    rows = int(len(features_mean)/2)
    
    plt.subplot(rows, 2, i+1)
    
    sns.boxplot(x='diagnosis', y=feature, data=data, palette="Set1")

plt.tight_layout()
plt.show()

# %% [markdown]
# # FEATURE REDUCTION AND FEATURE EXTRACTION

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import time
from subprocess import check_output

# %%
data = pd.read_csv('DataSet.csv')

# %%
full_data.describe()
plt.hist(full_data['diagnosis'])
plt.title('Diagnosis (M=1 , B=0)')
plt.show()

# %%
full_data
# Out:
#            id  diagnosis  radius_mean  texture_mean  perimeter_mean  \
# 0      842302          1    17.990000         10.38      122.800000
# 1      842517          1    20.570000         17.77      132.900000
# 2    84300903          1    19.690000         21.25       91.888373
# 3    84348301          1    11.420000         20.38       77.580000
# 4    84358402          1    20.290000         14.34      135.100000
# ..        ...        ...          ...           ...             ...
# 564    926424          1    21.560000         22.39      142.000000
# 565    926682          1    20.130000         28.25      131.200000
# 566    926954          1    16.600000         28.08      108.300000
# 567    927241          1    20.600000         29.33      140.100000
# 568     92751          0    14.124381         24.54       47.920000
#
#      area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0       1001.0          0.11225           0.27760         0.30010
# ...

# %%
df = full_data

# %%
df.to_csv('DataSet.csv')

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import time
from subprocess import check_output

# %%
data = pd.read_csv('DataSet.csv')

# %%
y = data.diagnosis                          # M or B 
list = ['Unnamed: 0','id','diagnosis']
x = data.drop(list,axis = 1 )
x.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38      122.800000     1001.0          0.11225
# 1        20.57         17.77      132.900000     1326.0          0.08474
# 2        19.69         21.25       91.888373     1203.0          0.10960
# 3        11.42         20.38       77.580000      386.1          0.14250
# 4        20.29         14.34      135.100000     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.01828         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %% [markdown]
# ## 1) Feature selection with correlation and random forest classification¶

# %%
f,ax = plt.subplots(figsize=(18, 18))
sns.heatmap(x.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
# Out:
# <AxesSubplot:>

# %%
drop_list1 = ['perimeter_mean','radius_mean','compactness_mean','concave points_mean','radius_se','perimeter_se','radius_worst','perimeter_worst','compactness_worst','concave points_worst','compactness_se','concave points_se','texture_worst','area_worst']
x_1 = x.drop(drop_list1,axis = 1 )   
x_1.head()
# Out:
#    texture_mean  area_mean  smoothness_mean  concavity_mean  symmetry_mean  \
# 0         10.38     1001.0          0.11225          0.3001         0.2419
# 1         17.77     1326.0          0.08474          0.0869         0.1812
# 2         21.25     1203.0          0.10960          0.1974         0.2069
# 3         20.38      386.1          0.14250          0.2414         0.2597
# 4         14.34     1297.0          0.10030          0.1980         0.1809
#
#    fractal_dimension_mean  texture_se  area_se  smoothness_se  concavity_se  \
# 0                 0.07871      0.9053  153.400       0.006399       0.05373
# 1                 0.05667      0.7339   74.080       0.005225       0.01860
# 2                 0.05999      0.7869   50.655       0.006150       0.03832
# 3                 0.09744      1.1560   27.230       0.009110       0.05661
# 4                 0.05883      0.7813   94.440       0.011490       0.05688
#
# ...

# %%
f,ax = plt.subplots(figsize=(14, 14))
sns.heatmap(x_1.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score,confusion_matrix
from sklearn.metrics import accuracy_score
x_train, x_test, y_train, y_test = train_test_split(x_1, y, test_size=0.3, random_state=42)
clf_rf = RandomForestClassifier(random_state=43)      
clr_rf = clf_rf.fit(x_train,y_train)
ac = accuracy_score(y_test,clf_rf.predict(x_test))
print('Accuracy is: ',ac)
cm = confusion_matrix(y_test,clf_rf.predict(x_test))
sns.heatmap(cm,annot=True,fmt="d")
# Out:
# Accuracy is:  0.9649122807017544
# <AxesSubplot:>

# %% [markdown]
# ## 2) Univariate feature selection and random forest classification

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
select_feature = SelectKBest(chi2, k=5).fit(x_train, y_train)

# %%
print('Score list:', select_feature.scores_)
print('Feature list:', x_train.columns)
# Out:
# Score list: [6.06916433e+01 3.66899557e+04 9.99989981e-02 1.30547650e+01
#  1.95982847e-01 3.42575072e-04 4.07131026e-02 6.01806797e+03
#  1.32470372e-03 6.92896719e-01 5.87141673e-03 2.65927071e-03
#  2.63226314e-01 2.58858117e+01 1.00635138e+00 1.23087347e-01]
# Feature list: Index(['texture_mean', 'area_mean', 'smoothness_mean', 'concavity_mean',
#        'symmetry_mean', 'fractal_dimension_mean', 'texture_se', 'area_se',
#        'smoothness_se', 'concavity_se', 'symmetry_se', 'fractal_dimension_se',
#        'smoothness_worst', 'concavity_worst', 'symmetry_worst',
#        'fractal_dimension_worst'],
#       dtype='object')

# %%
x_train_2 = select_feature.transform(x_train)
x_test_2 = select_feature.transform(x_test)
clf_rf_2 = RandomForestClassifier()      
clr_rf_2 = clf_rf_2.fit(x_train_2,y_train)
ac_2 = accuracy_score(y_test,clf_rf_2.predict(x_test_2))
print('Accuracy is: ',ac_2)
cm_2 = confusion_matrix(y_test,clf_rf_2.predict(x_test_2))
sns.heatmap(cm_2,annot=True,fmt="d")
# Out:
# Accuracy is:  0.9649122807017544
# <AxesSubplot:>

# %% [markdown]
# ## 3) Recursive feature elimination (RFE) with random forest

# %%
from sklearn.feature_selection import RFE
clf_rf_3 = RandomForestClassifier()      
rfe = RFE(estimator=clf_rf_3, n_features_to_select=5, step=1)
rfe = rfe.fit(x_train, y_train)

# %%
print('Chosen best 5 feature by rfe:',x_train.columns[rfe.support_])
# Out:
# Chosen best 5 feature by rfe: Index(['area_mean', 'concavity_mean', 'area_se', 'concavity_worst',
#        'symmetry_worst'],
#       dtype='object')

# %% [markdown]
# ## 4) Recursive feature elimination with cross validation and random forest classification

# %%
from sklearn.feature_selection import RFECV
clf_rf_4 = RandomForestClassifier() 
rfecv = RFECV(estimator=clf_rf_4, step=1, cv=5,scoring='accuracy')  
rfecv = rfecv.fit(x_train, y_train)

print('Optimal number of features :', rfecv.n_features_)
print('Best features :', x_train.columns[rfecv.support_])
# Out:
# Optimal number of features : 13
# Best features : Index(['texture_mean', 'area_mean', 'smoothness_mean', 'concavity_mean',
#        'fractal_dimension_mean', 'area_se', 'smoothness_se', 'concavity_se',
#        'fractal_dimension_se', 'smoothness_worst', 'concavity_worst',
#        'symmetry_worst', 'fractal_dimension_worst'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score of number of selected features")
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.show()

# %% [markdown]
# ## 5) Tree based feature selection and random forest classification

# %%
clf_rf_5 = RandomForestClassifier()      
clr_rf_5 = clf_rf_5.fit(x_train,y_train)
importances = clr_rf_5.feature_importances_
std = np.std([tree.feature_importances_ for tree in clf_rf.estimators_],axis=0)
indices = np.argsort(importances)[::-1]
print("Feature ranking:")
for f in range(x_train.shape[1]):
    print("%d. feature %d (%f)" % (f + 1, indices[f], importances[indices[f]]))
plt.figure(1, figsize=(14, 13))
plt.title("Feature importances")
plt.bar(range(x_train.shape[1]), importances[indices],
       color="g", yerr=std[indices], align="center")
plt.xticks(range(x_train.shape[1]), x_train.columns[indices],rotation=90)
plt.xlim([-1, x_train.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature 3 (0.233497)
# 2. feature 1 (0.195623)
# 3. feature 7 (0.160836)
# 4. feature 13 (0.141014)
# 5. feature 14 (0.049366)
# 6. feature 0 (0.036459)
# 7. feature 12 (0.029308)
# 8. feature 9 (0.024030)
# 9. feature 2 (0.022241)
# 10. feature 11 (0.020740)
# 11. feature 5 (0.019043)
# 12. feature 4 (0.014918)
# 13. feature 10 (0.014033)
# 14. feature 8 (0.013285)
# 15. feature 15 (0.013019)
# 16. feature 6 (0.012587)

# %% [markdown]
# ## Feature Extraction
# ### We will use principle component analysis (PCA) for feature extraction. Before PCA, we need to normalize data for better performance of PCA.

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)
x_train_N = (x_train-x_train.mean())/(x_train.max()-x_train.min())
x_test_N = (x_test-x_test.mean())/(x_test.max()-x_test.min())
from sklearn.decomposition import PCA
pca = PCA()
pca.fit(x_train_N)
plt.figure(1, figsize=(14, 13))
plt.clf()
plt.axes([.2, .2, .7, .7])
plt.plot(pca.explained_variance_ratio_, linewidth=2)
plt.axis('tight')
plt.xlabel('n_components')
plt.ylabel('explained_variance_ratio_')
# Out:
# Text(0, 0.5, 'explained_variance_ratio_')
